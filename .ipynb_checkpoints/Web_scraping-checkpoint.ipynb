# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, random, sys, time
from selenium import webdriver
import selenium
from bs4 import BeautifulSoup

# %%
browser = webdriver.Chrome('driver/chromedriver')
browser.get('https://www.xero.com/au/advisors/accountant/perks-899994fb204e/')

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src, 'lxml')
soup
# Out:
# <html class="js cors localstorage sessionstorage csspointerevents preserve3d supports no-touchevents flexbox flexboxlegacy no-flexboxtweener csstransforms3d csstransitions" lang="en" style=""><head class="mbox-name-geo-mbox at-element-marker" data-at-mbox-name="geo-mbox">
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Perks | Xero AU</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- Google Tag Manager (script) -->
# ...

# %%
name_div = soup.find('div', {'class': 'advisors-profile-hero-detailed-info'})
name_div
# Out:
# <div class="advisors-profile-hero-detailed-info">
# <h1 class="advisors-profile-hero-detailed-info-title title-2">Perks</h1>
# <p class="advisors-profile-hero-detailed-info-sub national">
#                                 Accountant
#                                 <span class="divider">·</span>
#                                 180 Greenhill Road, Parkside, SA
#                             </p>
# <div class="advisors-profile-hero-detailed-contact">
# <ul class="advisors-profile-hero-detailed-contact-list">
# <li>
# <button class="btn advisors-profile-hero-detailed-contact-send" data-advisor-id="c54049da-1ab8-4fc7-add9-75c40d8bae60" data-advisor-logo="https://s3.amazonaws.com/xero-prac-prod-practice-advisor-directory-images/3d49d55d-e67f-4bee-9d84-a5c9ca7ce295-1567500119" data-advisor-name="Perks" data-advisor-ref="JOm4iWEG84a9g3WFfBIyYy04hkD+Pvmp/9ie1TO9UAI=" type="button">Send message</button>
# </li>
# <li>
# ...

# %%
name = name_div.find('h1').get_text().strip()
name
# Out:
# 'Perks'

# %%
address = name_div.find('p').get_text().strip()
address
# Out:
# 'Accountant\n                                ·\n                                180 Greenhill Road, Parkside, SA'

# %%
## Website and phone

for link in name_div.find_all('a', href=True):
    print(link['href'])
# Out:
# http://www.perks.com.au
# tel:+61%20882739300

# %%
social_div = soup.find('div', {'class': 'advisor-profile-practice-block advisor-profile-practice-social'})
social_div
# Out:
# <div class="advisor-profile-practice-block advisor-profile-practice-social" data-gtm="ad-find-us-d8df9d73-6c55-4b88-8a15-899994fb204e">
# <h3 class="title-4 advisor-profile-practice-subtitle">Find us on the web</h3>
# <ul class="advisor-profile-practice-social-links">
# <li class="advisor-profile-practice-social-item">
# <a class="advisor-profile-practice-social-link" href="https://www.facebook.com/PerksAdelaide/" target="_blank">
# <svg class="icon icon-facebook advisor-profile-practice-social-icon" role="presentation">
# <use xlink:href="/etc/designs/xero-cms/clientlib/assets/img/svg-sprites/icon.svg#ico-facebook"></use>
# </svg>
#                   Facebook
#                 </a>
# </li>
# <li class="advisor-profile-practice-social-item">
# <a class="advisor-profile-practice-social-link" href="https://www.twitter.com/PerksAdelaide" target="_blank">
# <svg class="icon icon-twitter advisor-profile-practice-social-icon" role="presentation">
# ...

# %%
# Facebook, Twitter, Linkedin
for link in social_div.find_all('a', href=True):
    print(link['href'])
# Out:
# https://www.facebook.com/PerksAdelaide/
# https://www.twitter.com/PerksAdelaide
# https://www.linkedin.com/company/perks-accountants-wealth-advisers/?viewAsMember=true

# %%
partnership_div = soup.find('div', {'class': 'TagGroup__TagSection-sc-1xhwdnt-1 fSeEpq'})
partnership_div
# Out:
# <div class="TagGroup__TagSection-sc-1xhwdnt-1 fSeEpq" data-reactroot=""><div class="TagGroup TagGroup__GridWrapper-sc-1xhwdnt-2 bbEtFg Grid-sc-1cc3nlu-0 dDnXPq" data-gtm="d8df9d73-6c55-4b88-8a15-899994fb204e"><div class="Row-j9ftq3-0 Row WwKma"><div class="Col-dn6r69-0 eslfRl"><div class="SmallCard SmallCard__Wrapper-ikkojr-1 exqQEg"><div class="CardImage__ImageWrapper-k5ffc8-1 kKIHqQ"><img alt="STP Ready" class="Image CardImage__Image-k5ffc8-0 fASJIB" src="/content/dam/xero/images/advisors/single-touch-payroll-ready-ad.svg"/></div><div class="SmallCard__ContentWrapper-ikkojr-2 jTrtdh"><div class="Tag__TagWrapper-tkc026-0 gGAGXB CardHeader__Wrapper-sc-1jvagyh-0 fsjRdm" height="auto"><p class="CardHeader__CardPreTitle-sc-1jvagyh-1 xrbFQ PreTitle-sc-1jbmxtl-0 PreTitle gDlsex">Specialist</p><div class="Tag__TagHeadingWrapper-tkc026-1 jGlZUm"><h6 class="Tag__TagHeading-tkc026-2 fwRQWm Heading-sc-1h0g6oj-0 Heading gOuGWM">STP Ready </h6><div class="HintWrapper PopUp__HintWrapper-mmwpg7-0 
# ...

# %%
for link in partnership_div.find_all('img', alt=True):
    print(link['alt'])
# Out:
# STP Ready
# Xero Migration
# Platinum champion partner
# Partner since 2010
# Xero payroll certified
# Xero advisor certified

# %%
directors_div = soup.find('div', {'class': 'row advisors-profile-team-listings'})
directors_div
# Out:
# <div class="row advisors-profile-team-listings">
# <div class="small-12 advisors-profile-team-row">
# <article class="advisors-profile-team-item">
# <h3 class="title-3 advisors-profile-team-name">
#                             Tom Paine
#                         </h3>
# <p class="advisors-profile-team-role">
# <strong>Director</strong>
# </p>
# <figure class="advisors-profile-team-fig">
# <img alt="Profile image for Tom Paine" class="advisors-profile-team-photo" src="https://profiles.xero.com/image/d004f150-778d-4255-bbf9-cbd557f6d491_140x140.jpg"/>
# </figure>
# <button class="btn-expand advisors-profile-team-expand">
#                             Show
#                         </button>
# <div class="advisors-profile-team-expanded">
# <div class="advisors-profile-team-details">
# <ul class="advisors-profile-team-badges">
# <li class="advisors-profile-team-badge">
# <svg class="icon advisors-profile-team-icon" role="presentation">
# ...

# %%
for i in directors_div.find_all('strong'):
    role_data = i.text
    print(role_data)
# Out:
# Director
# Senior Manager
# Manager

# %%
for i in directors_div.find_all('h3'):
    name_data = i.text
    print(name_data)
# Out:
#                             Tom Paine
#
#
#                             Jenny Dunn
#
#
#                             Tyson Smith

# %%
for i in directors_div.find_all('li'):
    exp_data = i.text
    print(exp_data)
# Out:
#                                         Xero advisor certified
#                                         i
#
#
#                                                 Has a strong understanding and practical knowledge of how to use Xero with clients.
#
#
#
#
#
#
#
#
#                                         5 years Xerocon attendance
#
#
#
#
#
#                                         Xero advisor certified
#                                         i
#
#
#                                                 Has a strong understanding and practical knowledge of how to use Xero with clients.
#
#
#
#
#
#
#
#
#                                         2 years Xerocon attendance
#
#
#
#
#
#                                         Xero advisor certified
#                                         i
#
#
#                                                 Has a strong understanding and practical knowledge of how to use Xero with clients.
#
#
#
#
#
#
#
#
# ...
